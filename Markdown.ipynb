# %%
import pandas as pd

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# 1. list1
# 2. list2
# 3. list3
# - list1
# - list2
# - list3

# %% [markdown]
# $ x^2 $

# %% [markdown]
# $$
# x^2
# $$

# %% [markdown]
# $$
# \frac{arg1}{arg2} \\
# x^2 \\
# a_i \\
# b_{i} \\
# \sqrt[n]{arg1}
# $$
