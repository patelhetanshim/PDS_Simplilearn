# %%
def helloworld():
    print("Hello Wolrd,this is my first function.")

# %%
helloworld()
# Out:
# Hello Wolrd,this is my first function.

# %%
def add(x,y): # x and y are parameter
    return x+y #return keyword

# %%
#perameter and argunment
add(10,7) #argunments
# Out:
# 17

# %%
type(helloworld())
# Out:
# Hello Wolrd,this is my first function.
# NoneType

# %%
type(None)
# Out:
# NoneType
